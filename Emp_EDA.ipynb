# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Description of EDA:

# %% [markdown]
# EDA, which stands for Exploratory Data Analysis, refers to the process of analyzing and summarizing data sets in order to gain insights, discover patterns, and identify relationships or anomalies within the data. It is a crucial step in the data analysis pipeline and helps to understand the underlying structure and characteristics of the data.
#
# During EDA, various statistical techniques, visualizations, and data manipulation methods are applied to explore the data. The goals of EDA include:
#
# 1. Understanding the data: EDA aims to gain a deep understanding of the data by examining its distribution, range, and key statistics such as mean, median, and standard deviation. It involves assessing the quality, completeness, and consistency of the data.
#
# 2. Detecting patterns and relationships: EDA helps to identify patterns, trends, or relationships between variables within the data. This can involve exploring correlations, dependencies, or associations using techniques such as scatter plots, heatmaps, and correlation matrices.
#
# 3. Handling missing or inconsistent data: EDA involves examining missing values, outliers, or inconsistent data points. It may include strategies such as imputation of missing values, outlier detection, or data cleansing to ensure the data quality is suitable for further analysis.
#
# 4. Feature engineering and selection: EDA helps in identifying relevant features or variables that have a significant impact on the target variable. It involves assessing the importance and relevance of features, identifying redundant or irrelevant ones, and creating new features if necessary.
#
# 5. Visualization and communication: EDA often involves creating visualizations such as histograms, box plots, bar charts, or interactive dashboards to present the data visually. These visual representations help in understanding the data and effectively communicating the findings to stakeholders.
#
# Overall, EDA plays a crucial role in the data analysis process, providing a solid foundation for subsequent modeling, hypothesis testing, and decision-making. It helps in gaining insights, formulating hypotheses, and generating meaningful questions to guide further analysis and exploration of the data.

# %% [markdown]
# # Questions

# %% [markdown]
# # > Import the pandas library

# %% [markdown]
# This question involves importing the pandas library, a popular Python library used for data manipulation and analysis, It is a fundamental step in working with tabular data and performing various data operations.

# %% [markdown]
# Here, we have imported this python library to read the csv files

# %%
import pandas as pd
import scipy as stats

data = pd.read_csv('Emp_EDA.csv')
data
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %% [markdown]
# # < Remove the irrelevant column 'Senior Management '

# %% [markdown]
# Here, the task is to remove the 'Senior management' column from the dataset as it is deemed irrelevant for the analysis or does not contribute to the research objectives

# %%
data.drop(columns = ['Senior Management'], inplace=True)
data
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %% [markdown]
# # <Remove the duplicate rows and analyse

# %% [markdown]
# In this question, we need to identify and remove any duplicate rows from the dataset. Duplicate rows can skew analysis results and leat to incorrect insights. After removing duplicates, further analysis and insights can be derived from the cleaned dataset.

# %%
data.drop_duplicates(subset = "Gender", keep=False, inplace=True)
data
# Out:
#   First Name Gender  Salary                  Team   Age  Experience  \
# 7    Frances    NaN  139852  Business Development  34.0          10
#
#     New_Salary  Bonus
# 7  150374.4645  15500

# %% [markdown]
# # <Rename the column 'Bonus' to 'Incentive'

# %% [markdown]
# This question involves renaming the column 'Bonus' to 'Incentive' to align with the terminology or specific requirements of the analysis.

# %%
data.rename(columns={'Bonus':'Incentive'}, inplace=True)
data
# Out:
#   First Name Gender  Salary                  Team   Age  Experience  \
# 7    Frances    NaN  139852  Business Development  34.0          10
#
#     New_Salary  Incentive
# 7  150374.4645      15500

# %%
data1 = pd.read_csv('Emp_EDA.csv')

# %% [markdown]
# # <Calculate the central tendency measures for 'Experience'

# %% [markdown]
# Here, the task is to calculated the central tendency measures, such as mean, median, mode, for the 'Experience' column. These measures provide insights into the typical or central values of the variable

# %%
# 4) calculated the central tendency measures for 'Experience'
print("Mean value for experience column:")
mean = data1[["Experience"]].mean()
print(mean)

print()

print("Median value for the experience column:")
median = data1[["Experience"]].median()
print(median)

print()

print("Mode value for the experience column:")
mode = data1[["Experience"]].mode()
print(mode)
# Out:
# Mean value for experience column:
# Experience    13.68
# dtype: float64
#
# Median value for the experience column:
# Experience    12.0
# dtype: float64
#
# Mode value for the experience column:
#    Experience
# 0           5
# 1           7
# 2          10
# 3          11
# 4          12
# 5          13
# 6          15
# 7          26

# %% [markdown]
# # <Calculate the variability measures for 'Experience'

# %% [markdown]
# This question requires calculating variability measures, such as variance and standard deviation, for 'Experience' column. These measures quantify the dispersion or spread values around the central tendency, providing insights into the data's variability.

# %%
print('Range:', data1['Experience'].max() - data1['Experience'].min())
print('Variance:', data1['Experience'].var())
print('Standard Deviation:', data1['Experience'].std())
# Out:
# Range: 21
# Variance: 43.14333333333334
# Standard Deviation: 6.568358496103371

# %% [markdown]
# # <Calculate the IQR using quantile for 'Experience'

# %% [markdown]
# The interquartile range (IQR) is calculated using quantiles and provides information about the spread and distribution of data. This question involves calculating the IQR for the 'Experience' column, which helps identify the range where middle 50% of this data falls.

# %%
q1 = data1['Experience'].quantile(0.25)
q3 = data1['Experience'].quantile(0.75)
IQR = q3 - q1
print("IQR Value: ", IQR)
# Out:
# IQR Value:  9.0

# %% [markdown]
# # <Calculate the z-score for 'Experience'

# %% [markdown]
# The z-score measures how many standard deviations a data points is from the mean. This question involves calculating the z-scores for the 'Experience' column, which allows us to asses the relative position of each data point within the distribution.

# %%
import scipy
from scipy import stats
data1['Experience'].fillna(0, inplace=True)
data1['Experience_zscore']=stats.zscore(data1['Experience'])
data1
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %% [markdown]
# # >Add 2 rows at the end of the Dataframe

# %% [markdown]
# This question requires adding two rows at the end of the dataframe using the append method. The provided values are used to populate the new rows.

# %%
data.append({'First Name':'Zion', 'Gender':'Male', 'Salary':12345, 'Team':'Finance', 'Age':37.0, 'Experience':90, 'New_Salary':150374.4645, 'Incentive':2000}, ignore_index=True)
# Out:
# C:\Users\stanl\AppData\Local\Temp\ipykernel_6088\1725134721.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append({'First Name':'Zion', 'Gender':'Male', 'Salary':12345, 'Team':'Finance', 'Age':37.0, 'Experience':90, 'New_Salary':150374.4645, 'Incentive':2000}, ignore_index=True)
#   First Name Gender  Salary                  Team   Age  Experience  \
# 0    Frances    NaN  139852  Business Development  34.0          10
# 1       Zion   Male   12345               Finance  37.0          90
#
#     New_Salary  Incentive
# 0  150374.4645      15500
# 1  150374.4645       2000

# %%
data.append({'First Name':'Frances', 'Gender':'Male', 'Salary':13952, 'Team':'Business Development', 'Age':39.0, 'Experience':95, 'New_Salary':150374.5000, 'Incentive':15500}, ignore_index=True)
# Out:
# C:\Users\stanl\AppData\Local\Temp\ipykernel_6088\58543936.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append({'First Name':'Frances', 'Gender':'Male', 'Salary':13952, 'Team':'Business Development', 'Age':39.0, 'Experience':95, 'New_Salary':150374.5000, 'Incentive':15500}, ignore_index=True)
#   First Name Gender  Salary                  Team   Age  Experience  \
# 0    Frances    NaN  139852  Business Development  34.0          10
# 1       Zion   Male   12345               Finance  37.0          90
# 2       Zion   Male   12345               Finance  37.0          90
# 3       Zion   Male   12345               Finance  37.0          90
# 4    Frances   Male   13952  Business Development  39.0          95
#
#     New_Salary  Incentive
# 0  150374.4645      15500
# 1  150374.4645       2000
# 2  150374.4645       2000
# 3  150374.4645       2000
# 4  150374.5000      15500

# %% [markdown]
# # >Replace NAN with a given values

# %% [markdown]
# Here the task to replace any Nan(missing) values in the dataset with specified value. This ensures consistency and completeness in the dataset.

# %%
# Given value (salary=130590)
data2 = pd.read_csv('Emp_EDA.csv')
data2.fillna(130590)
# Out:
#    First Name  Gender  Salary                  Team       Age  Experience  \
# 0       Maria  Female  130590               Finance  130590.0           5
# 1      Angela  Female   54568  Business Development      27.0           5
# 2       Allan    Male  125792       Client Services      28.0           6
# 3       Rohan  Female   45906               Finance      28.0           7
# 4     Douglas    Male   97308             Marketing      28.0           7
# 5     Brandon    Male  112807       Human Resources      30.0           8
# 6       Diana  Female  132940       Client Services      31.0           9
# 7     Frances  130590  139852  Business Development      34.0          10
# 8     Matthew    Male  100612             Marketing      34.0          10
# 9       Larry    Male  101004       Client Services      35.0          11
# 10     Joshua    Male   90816       Client Services      35.0          11
# 11      Jerry    Male   72000               Finance      35.0          12
# ...

# %% [markdown]
# # >Replace the NaN value in the Salary column with previous value, next value, lunear interpolation, and central tendency measures:

# %% [markdown]
# This question handling missing values specifically in the Salaru column, Different techniques such as using the previous value, next value, linear interpolation, or central tendency measures(mean, median) can be used to fill in the missing values.

# %%
data3 = pd.read_csv('Emp_EDA.csv')
data3['Salary'].fillna(method='pad', inplace=True)
data3
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %%
data4 = pd.read_csv('Emp_EDA.csv')
data4['Salary'].fillna(method='bfill', inplace=True)
data4
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %%
data5 = pd.read_csv('Emp_EDA.csv')
data5['Salary'].interpolate(method='linear', limit_direction='foward', unplace=True)
data5
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %%
data6 = pd.read_csv('Emp_EDA.csv')
data6['Salary'].fillna(data['Salary'].mean(), inplace=True)
data6
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %%
data7 = pd.read_csv('Emp_EDA.csv')
data7['Salary'].fillna(data['Salary'].median(), inplace=True)
data7
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %% [markdown]
# # > Detect outliers in the updated 'Experience' column with boxplot, scatter plot, and histogram

# %% [markdown]
# Outliers are extreme values that significantly differ from other data points. This questio requires detecting outliers in the updated 'Experience' column using visual tecniques such as boxplot, scatter plot, and histogram. These visualizations help identify values that fall outside the expected range.

# %%
import matplotlib.pyplot as plt
data8 = pd.read_csv('Emp_EDA.csv')
plt.boxplot(data8['Experience'])
plt.show()

# %%
plt.plot(data8['Experience'], linewidth=0, marker='o', color='red')

# %%
plt.hist(data8['Experience'], edgecolor='black', color='red')
# Out:
# (array([5., 2., 4., 4., 3., 0., 1., 2., 1., 3.]),
#  array([ 5. ,  7.1,  9.2, 11.3, 13.4, 15.5, 17.6, 19.7, 21.8, 23.9, 26. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # > Remove the outliers using IQR by recalculating IQR inthe updated 'Experience' column and analyze with a box plot.

# %% [markdown]
# This question involves removing outliers froom the updated 'Experience' column using the interpuartile range (IQR) method. By recalculating the IQR and removing values outside a certain range, outliers can be effectively elimated. The analysis is then visualized using a box plot.

# %%
import numpy as np

Q1c = data7['Experience'].quantile(0.25)
Q3c = data7['Experience'].quantile(0.75)
IQRc = Q3c - Q1c
l = Q1c - 1.5 * IQRc
h = Q3c + 1.5 * IQRc

data7.loc[(data7['Experience'] < l) | (data7['Experience'] > h), 'Experience'] = np.nan

data7
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN         5.0
# 1      Angela  Female   54568  Business Development  27.0         5.0
# 2       Allan    Male  125792       Client Services  28.0         6.0
# 3       Rohan  Female   45906               Finance  28.0         7.0
# 4     Douglas    Male   97308             Marketing  28.0         7.0
# 5     Brandon    Male  112807       Human Resources  30.0         8.0
# 6       Diana  Female  132940       Client Services  31.0         9.0
# 7     Frances     NaN  139852  Business Development  34.0        10.0
# 8     Matthew    Male  100612             Marketing  34.0        10.0
# 9       Larry    Male  101004       Client Services  35.0        11.0
# 10     Joshua    Male   90816       Client Services  35.0        11.0
# 11      Jerry    Male   72000               Finance  35.0        12.0
# ...

# %% [markdown]
# # > Remove the outliers using z-score by recalculating z-score in the updated 'Experience' column and analyze it with a box plot.

# %% [markdown]
# This question requirres removing outliers from the updated 'Experience' column using the z-score method. By recalculating the z-scores and removing values exceed a certain threshold, outliers can be identified and removed. The Analysis is visualized using a box plot.

# %%
df_zscore = (data7['Age'] - data7['Age'].mean())/data7['Age'].std()
print(df_zscore)
# Out:
# 0          NaN
# 1    -1.297767
# 2    -1.180234
# 3    -1.180234
# 4    -1.180234
# 5    -0.945166
# 6    -0.827633
# 7    -0.475032
# 8    -0.475032
# 9    -0.357498
# 10   -0.357498
# 11   -0.357498
# 12   -0.357498
# 13   -0.239965
# 14   -0.122431
# 15   -0.004897
# 16    0.112636
# 17    0.112636
# 18    0.465237
# 19    0.700305
# 20    0.817838
# 21    1.287973
# 22    1.875641
# 23    1.993175
# 24    1.993175
# Name: Age, dtype: float64

# %% [markdown]
# # > Plot the Heatmap using correlation

# %% [markdown]
# This question involves plotting a heatmap to visualize the correlation between different variables in the dataset. Heatmaps provide an effective way to identify and analyze relationsips and dependencies between variables.

# %%
corr = data7.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\stanl\AppData\Local\Temp\ipykernel_6088\3201754247.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data7.corr()
# <style type="text/css">
# #T_72b34_row0_col0, #T_72b34_row1_col1, #T_72b34_row1_col2, #T_72b34_row2_col1, #T_72b34_row2_col2, #T_72b34_row3_col3, #T_72b34_row4_col4, #T_72b34_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72b34_row0_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_72b34_row0_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_72b34_row0_col3, #T_72b34_row3_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_72b34_row0_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# ...

# %% [markdown]
# # > Drop the last rows added in the dataframe

# %% [markdown]
# Finally, this question requires dropping the last two rows that were previously added to the dataframe. This ensures that the dataframe is reverted to its original state or structure.

# %%
data2.drop([23, 24], inplace=True)
data2
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# ...

# %% [markdown]
# # In conclusion
# EDA is a vital step in the data analysis process, providing a solid foundation for understanding and extracting insights from datasets. Through data visualization, statistical summaries, and exploration of relationships, EDA enables analysts to identify patterns, anomalies, and key features in the data. This knowledge empowers them to make informed decisions, solve complex problems, and drive positive outcomes across various domains. By embracing EDA, analysts can unleash the true potential of their data and unlock valuable insights that can shape strategies, optimize processes, and deliver tangible results.

# %% [markdown]
# # Contact Information:

# %% [markdown]
# Email: sffernandez06@gmail.com

# %% [markdown]
# Linkedin: https://www.linkedin.com/in/stanly-fernandez/

# %% [markdown]
# GitHub: https://github.com/Stanly06
